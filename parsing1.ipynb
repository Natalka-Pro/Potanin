# %% [markdown]
# # Библиотеки

# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import os
import re
import nltk

from tqdm.notebook import tqdm

# %%
def sim(s1, s2):
    return 1 - nltk.edit_distance(s1, s2)/ max(len(s1), len(s2))
    
def similarity(s1, s2):
    s1, s2 = s1.split(), s2.split()
    
    max_sim = 0
    for i in s1:
        for j in s2:
            max_sim = max(max_sim, sim(i, j))

    return max_sim


def max_common_part(name1, name2):
    if name1 == name2:
        return 1
    else:

        for i in range(min(len(name1), len(name2))):
            if name1[i] != name2[i]:
                break
        return i / min(len(name1), len(name2))

# %%
ls
# Out:
#  autors.csv       'Государственный архив Красноярского края и КККМ.docx'
#  autors.ods        КККМ/
#  demo.ipynb        КККМ_bin/
#  DocEnTR/          КККМ_bin.zip
#  my_rename.txt     КККМ_lines/
#  names.csv         КККМ_lines.zip
#  Natalia/          КККМ_myrenamed/
#  Natalia.gz        КККМ_myrenamed.zip
#  parsing1.ipynb    КККМ_pickles/
#  parsing2.ipynb    КККМ_pickles.zip
#  strokes_cut/      КККМ.zip
#  true_rename.txt

# %%
# !rm -r КККМ_clear

# %%
# !unzip КККМ.zip -d КККМ_clear

# %% [markdown]
# # Сравнение папок

# %%
# !rm -r КККМ
# !unzip КККМ.zip

# %%
# !unzip КККМ_myrenamed.zip

# %%
# FOLDER_CLEAR = "КККМ_clear/КККМ/"
# FOLDER = "КККМ"
from collections import defaultdict

FOLDER_CLEAR = "КККМ_myrenamed/" 
FOLDER = "КККМ/"


list_images_clear = sorted(os.listdir(FOLDER_CLEAR))
list_images = sorted(os.listdir(FOLDER))
print(len(list_images_clear), len(list_images))

name2clear = {}
# possible_names = set(list_images_clear)
possible_names = list_images_clear
used_names = defaultdict(list)

for name in tqdm(list_images):

    simm = 0
    near_clear_name = None

    for clear_name in possible_names:

        cur_sim = max_common_part(name, clear_name)
        if cur_sim > simm:
            simm = cur_sim
            near_clear_name = clear_name

    # if simm != 1:
    #     simm = 0
    #     near_clear_name = None
    #     for clear_name in tqdm(possible_names, disable=True):

    #         cur_sim = sim(name, clear_name)
    #         if cur_sim > simm:
    #             simm = cur_sim
    #             near_clear_name = clear_name

    name2clear[name] = (near_clear_name, simm)
    used_names[near_clear_name].append(name)
    # possible_names.discard(near_clear_name) # error not raised

# print(possible_names)
# КККМ ОФ 7928:817 Монякова.jpeg
# КККМ ОФ 7928:817 Муромов.jpeg
# Out:
# 2609 2606
#   0%|          | 0/2606 [00:00<?, ?it/s]

# %%
# from collections import Counter
# used_names = Counter(used_names)

for name, i in used_names.items():
    if len(i) > 1:
        print(name, i)
# Out:
# КККМ ОФ 7928:1513.jpeg ['КККМ ОФ 7928:1399 Музыкальное общество.jpeg', 'КККМ ОФ 7928:1513.jpeg', 'КККМ ОФ 7928:198 Богашев.jpeg', 'КККМ ОФ 7928:199 Богашев.jpeg']
# КККМ ОФ 7928:2335.jpeg ['КККМ ОФ 7928:200 Богашев.jpeg', 'КККМ ОФ 7928:231 Витвинова.jpeg', 'КККМ ОФ 7928:2335.jpeg', 'КККМ ОФ 7928:2387 ВСО РГО.jpeg']
# ...

# %%
for name, (clear_name, sim) in name2clear.items():
    if sim != 1:
        print(f"# {name} -> {clear_name} {sim}")
# Out:
# # КККМ ОФ 7928:1144 Сибиряков А.jpeg -> КККМ ОФ 7928:1144 Сибирякова.jpeg 0.8181818181818182
# # КККМ ОФ 7928:115 Букейфанов.jpeg -> КККМ ОФ 7928:115 Букейханов.jpeg 0.6875
# # КККМ ОФ 7928:1155 Строхова.jpeg -> КККМ ОФ 7928:1155 Страхова.jpeg 0.6774193548387096
# # КККМ ОФ 7928:116 Букейфанов.jpeg -> КККМ ОФ 7928:116 Букейханов.jpeg 0.6875
# # КККМ ОФ 7928:117 Букейфанов.jpeg -> КККМ ОФ 7928:117 Букейханов.jpeg 0.6875
# # КККМ ОФ 7928:118 Букейфанов.jpeg -> КККМ ОФ 7928:118 Букейханов.jpeg 0.6875
# # КККМ ОФ 7928:119 Букейфанов.jpeg -> КККМ ОФ 7928:119 Букейханов.jpeg 0.6875
# # КККМ ОФ 7928:1306 Чарушин.jpeg -> КККМ ОФ 7928:1306 Чарушина.jpeg 0.8333333333333334
# # КККМ ОФ 7928:1399 Музыкальное общество.jpeg -> КККМ ОФ 7928:1513.jpeg 0.6363636363636364
# # КККМ ОФ 7928:1501 Корниловы.jpeg -> КККМ ОФ 7928:1501 Корнилова Корнилов А.jpeg 0.8125
# # КККМ ОФ 7928:1504 Солдатовы.jpeg -> КККМ ОФ 7928:1504 Солдатов.jpeg 0.8387096774193549
# ...

# %% [markdown]
# # Чтение таблицы

# %%
df = pd.read_csv('autors.csv')
df
# Out:
#                    Шифр                                    Адресат  Кол-во  \
# 0      КККМ ОФ 3269/323              Красноженова Мария Васильевна     1.0
# 1        КККМ ОФ 7928/5                            Редакция газеты     1.0
# 2        КККМ ОФ 7928/9                     Макеров Яков Антонович     1.0
# 3       КККМ ОФ 7928/10                    Зубашев Ефим Лукьянович     1.0
# 4       КККМ ОФ 7928/11                    Окулич Николай Иванович     1.0
# ...                 ...                                        ...     ...
# 2697  КККМ ОФ 7928/2968                                  Отелин С.     1.0
# 2698  КККМ ОФ 7928/2969                                      Сулье     1.0
# 2699  КККМ ОФ 7928/2970                                  Отелин С.     1.0
# 2700   КККМ ОФ 10369/27  Минусинский городской Мартьяновский музей     1.0
# 2701                NaN                 Шашков Серафим Серафимович     1.0
#
#               Листы        Дата  \
# 0                 1         NaN
# ...

# %%
df = df.to_numpy()
df = df[:, :2]
df
# Out:
# array([['КККМ ОФ 3269/323', 'Красноженова Мария Васильевна'],
#        ['КККМ ОФ 7928/5', 'Редакция газеты'],
#        ['КККМ ОФ 7928/9', 'Макеров Яков Антонович'],
#        ...,
#        ['КККМ ОФ 7928/2970', 'Отелин С.'],
#        ['КККМ ОФ 10369/27', 'Минусинский городской Мартьяновский музей'],
#        [nan, 'Шашков Серафим Серафимович']], dtype=object)

# %%
s = 'Красноженова.... Мария Васильевна'
pattern = r"[^а-яА-Я]"
print(re.sub(pattern, " ", s))
# Out:
# Красноженова     Мария Васильевна

# %% [markdown]
# # table_num2name

# %%
table_num2name = {}

for num, name in df:
    
    if isinstance(num, str):
        num = num.strip().split()
        num = [i for i in num if i[0].isnumeric()]

        # if len(num) != 1:
        #     print(num, name)
        #     break

        num = num[0].replace("/", ":")
        
        # print(num)
        # break
        pattern = r"[^а-яА-ЯёЁ]"
        name = re.sub(pattern, " ", name) # убираем всё, что не русские буквы
        name = " ".join(name.split())

        if num not in table_num2name:
            table_num2name[num] = name
        else:
            print(num, name, ", Already - ", table_num2name[num])
# Out:
# 7928:755 Григорьева П А , Already -  Лосева Е
# 7928:1272 Фарафонтова Таисия Михайловна , Already -  Фарафонтова Таисия Михайловна
# 7928:1530 Потанин к Новомбергской Вере Алексеевне , Already -  Новомбергская Вера Алексеевна

# %% [markdown]
# # num2name

# %%
num2name = {}

list_images = sorted(os.listdir("КККМ"))

for img in list_images:
    if not os.path.isdir(f"КККМ/{img}"):

        img = os.path.splitext(img)[0]
        num, *name = img.strip().split()[2:]
        name = " ".join(name)

        pattern = r"[^а-яА-ЯёЁ]"
        name = re.sub(pattern, " ", name) # убираем всё, что не русские буквы
        name = " ".join(name.split())

        if num not in num2name:
            num2name[num] = name
        else:
            print(num, name, ", Already - ", num2name[num])
# Out:
# 7928:1404 Общество изучения Сибири , Already -  Начальник СЖД
# 7928:2150 Ржавская , Already -  Ржавская
# 7928:351 Григорьев , Already -  Григорьев В
# 7928:467 Зверев , Already -  Зверев
# 7928:820 Минаева , Already -  Минаева А

# %%
list_images = sorted(os.listdir("КККМ"))

table_num2name["7928:1448"] = "Императорское Русское географическое общество"

DICTIONARY = {
            #   "Лаврская А" : "Потанина Александра Викторовна",
              "ВСО РГО" : "Восточно Сибирский отдел Императорского Русского географического общества",
              "РГО" : "Императорское Русское географическое общество",
              "СП РГО" : "Семипалатинский подотдел Западно Сибирского отдела Императорского Русского географического общества Ницкевич Н Коншин Николай Яковлевич",
              "ОИС" : "Томское Общество изучения Сибири",
              "ЗСО РГО" : "Западно Сибирский отдел Императорского Русского географического общества",
              "ТО РМО" : "Томское отделение Императорского Русского музыкального общества",
              "ПО РГО" : "Троицкосавско Кяхтинское отделение Приамурского отдела Императорского Русского географического общества",
              "Балакшины" : "Балакшин Александр Николаевич Балакшина",
              "Багашев" : "Прошение в Главное управление по делам печати И Богашев",
              "Крутовские" : "Крутовский Владимир Михайлович Крутовская Лидия Симоновна",
              "Лаврские А и В" : "Лаврская Антонина Викторовна Лаврский Валериан Викторович",
              "Общество изучения Сибири" : "Начальник коммерческой части Сибирской железной дороги",
              "Учительский союз" : "Томская группа Учительского союза",
              "Ректор" : "Неустановленное лицо ректор",
              "Педобщество" : "Совет Томского педагогического общества",
              "Мокиевские и др" : "Мокиевская Мокиевский П Выхарева Юферова Лихарева",
              "Новомбергские Троицкие и др" : "Новомбергский Николай Яковлевич Новомбергская Вера Алексеевна Троицкий Троицкая М Фоняков Фонякова Долин",
              "Пантелеевы" : "Пантелеев Лонгин Федорович Пантелеева Серафима Васильевна",
              "Проскуряковы" : "Проскуряков Павел Степанович Проскурякова",
              "Сссыльные" : "Конев О Мокрецов В Сушилов Г Г Соболев Афанасий Гаврилович И др",
              "Томские высшие курсы" : "Попечительский совет Томских высших историко философских курсов",
              }

def dict_match(name):
    return DICTIONARY.get(name, "")




sus = []
matching = {}

for img in list_images:
    if not os.path.isdir(f"КККМ/{img}"):

        img = os.path.splitext(img)[0]
        num, *name = img.strip().split()[2:]
        name = " ".join(name)

        pattern = r"[^а-яА-ЯёЁ]"
        name = re.sub(pattern, " ", name) # убираем всё, что не русские буквы
        name = " ".join(name.split())

        # print(img, name, img, sep = " # ")
        
        if num not in table_num2name:
            print("!!!! ", img)
            continue

        table_name = table_num2name[num]
        dist = similarity(name, table_name)
        
        if (len(name) == 0 and ("Неустановленное лицо" in table_name)) or dist == 1 or dict_match(name) == table_name:

            if name not in matching:
                matching[name] = {"table" : set(), "count" : 0}
            matching[name]["table"].add(table_name)
            matching[name]["count"] += 1
            continue
        else:
            sus.append((img, name, table_name, dist))
            # print(name, table_name, dist, sep = " # ")
            
            # flag = False

            # for partname in name:
            #     if partname in num2name[num].strip().split():
            #         flag = True
            
            # if not flag:
            #     print(2, img, name, num2name[num], "", sep=" ||| ")


matching = sorted([(name, table_name) for name, table_name in matching.items()], key = lambda x: x[0])

# КККМ ОФ 7928:1387Томилов.jpeg -> КККМ ОФ 7928:1387 Томилов.jpeg
# КККМ ОФ 7928:1181.jpeg -> КККМ ОФ 7928:1181 Соловкин.jpeg
# КККМ ОФ 7928:1819 Кетрин.jpeg -> КККМ ОФ 7928:1819 Кетриц.jpeg
# КККМ ОФ 7928:2434 Кетрин.jpeg -> КККМ ОФ 7928:2434 Кетриц.jpeg
# КККМ ОФ 7928:198 Богашев.jpeg -> КККМ ОФ 7928:198 Багашев.jpeg
# КККМ ОФ 7928:199 Богашев.jpeg -> КККМ ОФ 7928:199 Багашев.jpeg
# КККМ ОФ 7928:200 Богашев.jpeg -> КККМ ОФ 7928:200 Багашев.jpeg
# КККМ ОФ 7928:791 Маакушина.jpeg -> КККМ ОФ 7928:791 Макушина.jpeg
# КККМ ОФ 7928:155 Балобикова.jpeg -> КККМ ОФ 7928:155 Балобанова.jpeg
# КККМ ОФ 7928:115 Букейфанов.jpeg -> КККМ ОФ 7928:115 Букейханов.jpeg
# КККМ ОФ 7928:116 Букейфанов.jpeg -> КККМ ОФ 7928:116 Букейханов.jpeg
# КККМ ОФ 7928:117 Букейфанов.jpeg -> КККМ ОФ 7928:117 Букейханов.jpeg
# КККМ ОФ 7928:118 Букейфанов.jpeg -> КККМ ОФ 7928:118 Букейханов.jpeg
# КККМ ОФ 7928:119 Букейфанов.jpeg -> КККМ ОФ 7928:119 Букейханов.jpeg
# КККМ ОФ 7928:404 Грячкина.jpeg -> КККМ ОФ 7928:404 Горячкина.jpeg
# КККМ ОФ 7928:628 Лаврская А.jpeg -> КККМ ОФ 7928:628 Потанина А.jpeg
# КККМ ОФ 7928:629 Лаврская А.jpeg -> КККМ ОФ 7928:629 Потанина А.jpeg
# КККМ ОФ 7928:630 Лаврская А.jpeg -> КККМ ОФ 7928:630 Потанина А.jpeg
# КККМ ОФ 7928:631 Лаврская А.jpeg -> КККМ ОФ 7928:631 Потанина А.jpeg
# КККМ ОФ 7928:632 Лаврская А.jpeg -> КККМ ОФ 7928:632 Потанина А.jpeg
# КККМ ОФ 7928:633 Лаврская А.jpeg -> КККМ ОФ 7928:633 Потанина А.jpeg
# КККМ ОФ 7928:634 Лаврская А.jpeg -> КККМ ОФ 7928:634 Потанина А.jpeg
# КККМ ОФ 7928:635 Лаврская А.jpeg -> КККМ ОФ 7928:635 Потанина А.jpeg
# КККМ ОФ 7928:636 Лаврская А.jpeg -> КККМ ОФ 7928:636 Потанина А.jpeg
# КККМ ОФ 7928:637 Лаврская А.jpeg -> КККМ ОФ 7928:637 Потанина А.jpeg
# КККМ ОФ 7928:638 Лаврская А.jpeg -> КККМ ОФ 7928:638 Потанина А.jpeg
# КККМ ОФ 7928:639 Лаврская А.jpeg -> КККМ ОФ 7928:639 Потанина А.jpeg
# КККМ ОФ 7928:640 Лаврская А.jpeg -> КККМ ОФ 7928:640 Потанина А.jpeg
# КККМ ОФ 7928:641 Лаврская А.jpeg -> КККМ ОФ 7928:641 Потанина А.jpeg
# КККМ ОФ 7928:690 Леонтович В.jpeg -> КККМ ОФ 7928:690 Леонович В.jpeg
# КККМ ОФ 7928:691 Леонтович В.jpeg -> КККМ ОФ 7928:691 Леонович В.jpeg
# КККМ ОФ 7928:692 Леонтович В.jpeg -> КККМ ОФ 7928:692 Леонович В.jpeg
# КККМ ОФ 7928:693 Леонтович В.jpeg -> КККМ ОФ 7928:693 Леонович В.jpeg
# КККМ ОФ 7928:694 Леонтович В.jpeg -> КККМ ОФ 7928:694 Леонович В.jpeg
# КККМ ОФ 7928:791 Маакушина.jpeg -> КККМ ОФ 7928:791 Макушина.jpeg
# КККМ ОФ 7928:820 М.Ф.М.jpeg -> КККМ ОФ 7928:820 Минаева А.jpeg
# КККМ ОФ 7928:956 Роборовская.jpeg -> КККМ ОФ 7928:956 Роборовский.jpeg
# КККМ ОФ 7928:817 Монякова.jpeg -> КККМ ОФ 7928:817 Муромов.jpeg
""".split("\n")

text = sorted(text)
true = sorted(true)
print(len(text), len(true))
# Out:
# 70 70

# %%
for i in range(len(text)):
    if text[i] != true[i]:
        print(text[i], len(text[i]))
        print(true[i], len(true[i]))
        break

# %%
m = max_common_part(text[i], true[i])
text[i][m:]
# Out:
# 'oгашев.jpeg -> КККМ ОФ 7928:200 Багашев.jpeg'

# %%
# for i in range(612, 641 + 1):
#     DIR = "КККМ"
#     name =     f"КККМ ОФ 7928:{i} Лаврская А"
#     new_name = f"КККМ ОФ 7928:{i} Потанина А"
#     file = f"{DIR}/{name}.jpeg"
#     new_file = f"{DIR}/{new_name}.jpeg"
#     print(f"# {name}.jpeg -> {new_name}.jpeg")

#     !mv "$file" "$new_file"

# %%
DIR = "КККМ"
TMP_DIR = "TMP1"

# !rm -r "$TMP_DIR"

if not os.path.exists(TMP_DIR):
    # !mkdir "$TMP_DIR"

fun = lambda x : "Сибирякова" in x # or "Григорьева " in x

for img in list_images:
    if fun(img):
        path = f"{DIR}/{img}"
        new_path = f"{TMP_DIR}/{img}"
        # !cp "$path" "$new_path"
# Out:
# rm: cannot remove 'TMP1': No such file or directory

# %%
DIR = "КККМ"
TMP_DIR = "TMP2"

# !rm -r "$TMP_DIR"

if not os.path.exists(TMP_DIR):
    # !mkdir "$TMP_DIR"

fun = lambda x : "Сибиряков" in x and "Сибирякова" not in x # or "Григорьева " in x

for img in list_images:
    if fun(img):
        path = f"{DIR}/{img}"
        new_path = f"{TMP_DIR}/{img}"
        # !cp "$path" "$new_path"
# Out:
# rm: cannot remove 'TMP2': No such file or directory

# %%
DIR = "КККМ"
name =     "КККМ ОФ 7928:1155 Строхова"
new_name = "КККМ ОФ 7928:1155 Страхова"
file = f"{DIR}/{name}.jpeg"
new_file = f"{DIR}/{new_name}.jpeg"
print(f"# {name}.jpeg -> {new_name}.jpeg")

# !mv "$file" "$new_file"
# Out:
# # КККМ ОФ 7928:1155 Строхова.jpeg -> КККМ ОФ 7928:1155 Страхова.jpeg

# %%
for img, name, table_name, dist in sorted(sus, key = lambda x : x[1]):
    print(f'"{name}" : "{table_name}", {dist} - {img}')

# %%
for name, table_name in matching:
    print(f'"{name}" : "{table_name["table"]}" - {table_name["count"]}')
# Out:
# "" : "{'Неустановленное лицо случайный сибиряк', 'Неустановленное лицо томский рабочий', 'Неустановленное лицо', 'Неустановленное лицо из с Огундай'}" - 36
# "Агафонов" : "{'Агафонов Николай Яковлевич'}" - 1
# "Адлер" : "{'Адлер Б'}" - 1
# "Адресный стол" : "{'Санкт Петербургский адресный стол'}" - 6
# "Адрианов" : "{'Адрианов Александр Васильевич'}" - 23
# "Адрианова" : "{'Адрианова Нина Александровна'}" - 1
# "Азанчевский" : "{'Азанчевский Азанчеев Всеволод Николаевич'}" - 1
# "Акерблом" : "{'Акерблом Сергей Иванович'}" - 3
# "Акпаев" : "{'Акпаев Жакып'}" - 1
# "Александров" : "{'Александров П'}" - 1
# "Алексеевский" : "{'Алексеевский Владимир Петрович'}" - 1
# "Альджанов" : "{'Альджанов Альжанов Отыншы Отунчи'}" - 2
# "Андреев" : "{'Андреев В', 'Андреев Н'}" - 2
# "Андреев Н" : "{'Андреев Н'}" - 1
# "Андреев и Николаев" : "{'Андреев В Николаев Н'}" - 1
# "Андреева" : "{'Андреева Анна', 'Андреева Е П'}" - 3
# "Анненский" : "{'Анненский Николай Федорович'}" - 2
# ...

# %%
s1 = '132123131322'
s2 = 'Сементовская'
print(s1)
print(s2)
print(1 - nltk.edit_distance(s1, s2)/ max(len(s1), len(s2)))
# Out:
# 132123131322
# Сементовская
# 0.0
