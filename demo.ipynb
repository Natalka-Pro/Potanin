# %%
# ! git clone https://github.com/dali92002/DocEnTR

# %%
pwd
# Out:
# '/home/natalkaser/mmp/Potanin/DocEnTR'

# %%
cd DocEnTR/
# Out:
# [Errno 2] No such file or directory: 'DocEnTR/'
# /home/natalkaser/mmp/Potanin/DocEnTR

# %%
# !which python
# Out:
# /home/natalkaser/mmp/Potanin/env3.8/bin/python

# %%
# !cat requirements.txt
# Out:
# einops==0.3.2
# matplotlib==3.5.0
# numpy==1.21.5
# opencv_python==4.5.4.60
# Pillow==9.0.0
# thinc==8.0.13
# torch==1.10.0
# torchvision==0.11.1
# tqdm==4.62.3
# vit_pytorch==0.24.3

# %%
# !pip install einops==0.3.2
# Out:
# Requirement already satisfied: einops==0.3.2 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (0.3.2)

# %%
# !pip install matplotlib==3.5.0
# Out:
# Collecting matplotlib==3.5.0
#   Using cached matplotlib-3.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.7 kB)
# Collecting cycler>=0.10 (from matplotlib==3.5.0)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.5.0)
#   Using cached fonttools-4.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.5.0)
#   Using cached kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.3 kB)
# Collecting numpy>=1.17 (from matplotlib==3.5.0)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging>=20.0 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from matplotlib==3.5.0) (24.2)
# Collecting pillow>=6.2.0 (from matplotlib==3.5.0)
#   Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.5.0)
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from matplotlib==3.5.0) (2.9.0.post0)
# Collecting setuptools-scm>=4 (from matplotlib==3.5.0)
#   Using cached setuptools_scm-8.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: six>=1.5 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib==3.5.0) (1.17.0)
# Requirement already satisfied: setuptools>=61 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (68.1.2)
# Requirement already satisfied: tomli>=1 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (4.12.2)
# Using cached matplotlib-3.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
# Using cached kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Using cached setuptools_scm-8.2.0-py3-none-any.whl (43 kB)
# Installing collected packages: setuptools-scm, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.7 matplotlib-3.5.0 numpy-1.24.4 pillow-10.4.0 pyparsing-3.1.4 setuptools-scm-8.2.0

# %%
# !pip install tqdm==4.62.3
# Out:
# Collecting tqdm==4.62.3
#   Using cached tqdm-4.62.3-py2.py3-none-any.whl.metadata (56 kB)
# Using cached tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.62.3

# %%
# !pip install opencv_python==4.5.4.60
# Out:
# Collecting opencv_python==4.5.4.60
#   Using cached opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.17.3 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from opencv_python==4.5.4.60) (1.24.4)
# Using cached opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
# Installing collected packages: opencv_python
# Successfully installed opencv_python-4.5.4.60

# %%
# !pip install numpy==1.21.5
# Out:
# Collecting numpy==1.21.5
#   Using cached numpy-1.21.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.1 kB)
# Using cached numpy-1.21.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed numpy-1.21.5

# %%
# !pip install Pillow==9.0.0
# Out:
# Collecting Pillow==9.0.0
#   Using cached Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Using cached Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.4.0
#     Uninstalling pillow-10.4.0:
#       Successfully uninstalled pillow-10.4.0
# Successfully installed Pillow-9.0.0

# %%
# !pip install thinc
# Out:
# Collecting thinc
#   Downloading thinc-8.3.2.tar.gz (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193
/s eta 0:00:00
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × pip subprocess to install build dependencies did not run successfully.
#         │ exit code: 1
#         ╰─> [8 lines of output]
#             Collecting setuptools
#               Using cached setuptools-75.3.0-py3-none-any.whl.metadata (6.9 kB)
#             Collecting cython>=0.25
#               Using cached Cython-3.0.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
#             ERROR: Ignored the following versions that require a different python version: 1.25.0 Requires-Python >=3.9; 1.25.1 Requires-Python >=3.9; 1.25.2 Requires-Python >=3.9; 1.26.0 Requires-Python <3.13,>=3.9; 1.26.1 Requires-Python <3.13,>=3.9; 1.26.2 Requires-Python >=3.9; 1.26.3 Requires-Python >=3.9; 1.26.4 Requires-Python >=3.9; 2.0.0 Requires-Python >=3.9; 2.0.1 Requires-Python >=3.9; 2.0.2 Requires-Python >=3.9; 2.1.0 Requires-Python >=3.10; 2.1.0rc1 Requires-Python >=3.10; 2.1.1 Requires-Python >=3.10; 2.1.2 Requires-Python >=3.10; 2.1.3 Requires-Python >=3.10; 2.2.0 Requires-Python >=3.10; 2.2.0rc1 Requires-Python >=3.10; 2.2.1 Requires-Python >=3.10; 2.2.2 Requires-Python >=3.10; 2.2.3 Requires-Python >=3.10; 75.4.0 Requires-Python >=3.9; 75.5.0 Requires-Python >=3.9; 75.6.0 Requires-Python >=3.9; 75.7.0 Requires-Python >=3.9; 75.8.0 Requires-Python >=3.9; 75.8.1 Requires-Python >=3.9; 75.8.2 Requires-Python >=3.9
#             ERROR: Could not find a version that satisfies the requirement numpy<3.0.0,>=2.0.0 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.21.2, 1.21.3, 1.21.4, 1.21.5, 1.21.6, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4)
#             ERROR: No matching distribution found for numpy<3.0.0,>=2.0.0
#
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: subprocess-exited-with-error
#
#       × pip subprocess to install build dependencies did not run successfully.
#       │ exit code: 1
#       ╰─> See above for output.
#
#       note: This error originates from a subprocess, and is likely not a problem with pip.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install thinc==8.0.13
# This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed building wheel for murmurhash
# Failed to build cymem murmurhash
# ERROR: Could not build wheels for cymem, murmurhash, which is required to install pyproject.toml-based projects

# %%
# !pip install torchvision==0.11.1
# Out:
# Collecting torchvision==0.11.1
#   Using cached torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torchvision==0.11.1) (1.21.5)
# Requirement already satisfied: torch==1.10.0 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torchvision==0.11.1) (1.10.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torchvision==0.11.1) (9.0.0)
# Requirement already satisfied: typing-extensions in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torch==1.10.0->torchvision==0.11.1) (4.12.2)
# Using cached torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.11.1

# %%
# !pip install torch==1.10.0
# Out:
# Collecting torch==1.10.0
#   Using cached torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: typing-extensions in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torch==1.10.0) (4.12.2)
# Using cached torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
# Installing collected packages: torch
# Successfully installed torch-1.10.0

# %%
# !pip install vit_pytorch==0.24.3
# Out:
# Collecting vit_pytorch==0.24.3
#   Using cached vit_pytorch-0.24.3-py3-none-any.whl.metadata (686 bytes)
# Requirement already satisfied: einops>=0.3 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from vit_pytorch==0.24.3) (0.3.2)
# Requirement already satisfied: torch>=1.6 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from vit_pytorch==0.24.3) (1.10.0)
# Requirement already satisfied: torchvision in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from vit_pytorch==0.24.3) (0.11.1)
# Requirement already satisfied: typing-extensions in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torch>=1.6->vit_pytorch==0.24.3) (4.12.2)
# Requirement already satisfied: numpy in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torchvision->vit_pytorch==0.24.3) (1.21.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torchvision->vit_pytorch==0.24.3) (9.0.0)
# Using cached vit_pytorch-0.24.3-py3-none-any.whl (45 kB)
# Installing collected packages: vit_pytorch
# Successfully installed vit_pytorch-0.24.3

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: einops==0.3.2 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (0.3.2)
# Collecting matplotlib==3.5.0 (from -r requirements.txt (line 2))
#   Using cached matplotlib-3.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.7 kB)
# Collecting numpy==1.21.5 (from -r requirements.txt (line 3))
#   Using cached numpy-1.21.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.1 kB)
# Collecting opencv_python==4.5.4.60 (from -r requirements.txt (line 4))
#   Using cached opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting Pillow==9.0.0 (from -r requirements.txt (line 5))
#   Using cached Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Collecting thinc==8.0.13 (from -r requirements.txt (line 6))
#   Using cached thinc-8.0.13-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting torch==1.10.0 (from -r requirements.txt (line 7))
#   Using cached torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.11.1 (from -r requirements.txt (line 8))
#   Using cached torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl.metadata (8.8 kB)
# Collecting tqdm==4.62.3 (from -r requirements.txt (line 9))
#   Using cached tqdm-4.62.3-py2.py3-none-any.whl.metadata (56 kB)
# Collecting vit_pytorch==0.24.3 (from -r requirements.txt (line 10))
#   Using cached vit_pytorch-0.24.3-py3-none-any.whl.metadata (686 bytes)
# Collecting cycler>=0.10 (from matplotlib==3.5.0->-r requirements.txt (line 2))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.5.0->-r requirements.txt (line 2))
#   Using cached fonttools-4.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.5.0->-r requirements.txt (line 2))
#   Using cached kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from matplotlib==3.5.0->-r requirements.txt (line 2)) (24.2)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.5.0->-r requirements.txt (line 2))
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from matplotlib==3.5.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Collecting setuptools-scm>=4 (from matplotlib==3.5.0->-r requirements.txt (line 2))
#   Using cached setuptools_scm-8.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting blis<0.8.0,>=0.4.0 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached murmurhash-1.0.12.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cymem<2.1.0,>=2.0.2 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting preshed<3.1.0,>=3.0.2 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting wasabi<1.1.0,>=0.8.1 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.0 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.4 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: setuptools in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from thinc==8.0.13->-r requirements.txt (line 6)) (68.1.2)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 (from thinc==8.0.13->-r requirements.txt (line 6))
#   Using cached pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl.metadata (103 kB)
# Requirement already satisfied: typing-extensions in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from torch==1.10.0->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib==3.5.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: tomli>=1 in /home/natalkaser/mmp/Potanin/env3.8/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib==3.5.0->-r requirements.txt (line 2)) (2.2.1)
# Using cached matplotlib-3.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
# Using cached numpy-1.21.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Using cached opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
# Using cached Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# Using cached thinc-8.0.13-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (636 kB)
# Downloading torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.9/881.9 MB 482.3 kB/s eta 0:00:00 eta 0:00:010:00:09m
# Downloading torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 3.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 5.9 MB/s eta 0:00:00
# Downloading vit_pytorch-0.24.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 664.8 kB/s eta 0:00:001m40.0 MB/s eta 0:00:01
# Downloading blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 5.0 MB/s eta 0:00:00m eta 0:00:01:01:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.2/154.2 kB 2.6 MB/s eta 0:00:003.4 MB/s eta 0:00:01
# Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.0 MB/s eta 0:00:00
# Downloading setuptools_scm-8.2.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 647.3 kB/s eta 0:00:00MB/s eta 0:00:01
# Downloading srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.3/494.3 kB 11.1 MB/s eta 0:00:00m eta 0:00:01
# Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Building wheels for collected packages: cymem, murmurhash
#   Building wheel for cymem (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for cymem (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/__init__.py -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/about.py -> build/lib.linux-x86_64-cpython-38/cymem
#       creating build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/tests/test_import.py -> build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/cymem.pyx -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/cymem.pxd -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/__init__.pxd -> build/lib.linux-x86_64-cpython-38/cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       creating build/temp.linux-x86_64-cpython-38/cymem
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/home/natalkaser/mmp/Potanin/env3.8/include -I/usr/include/python3.8 -c cymem/cymem.cpp -o build/temp.linux-x86_64-cpython-38/cymem/cymem.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       cymem/cymem.cpp:33:10: fatal error: Python.h: No such file or directory
#          33 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/bin/x86_64-linux-gnu-g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cymem
#   Building wheel for murmurhash (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for murmurhash (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [30 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/__init__.py -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/about.py -> build/lib.linux-x86_64-cpython-38/murmurhash
#       creating build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/test_hash.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/test_import.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/mrmr.pyx -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/mrmr.pxd -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/__init__.pxd -> build/lib.linux-x86_64-cpython-38/murmurhash
#       creating build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       copying murmurhash/include/murmurhash/MurmurHash3.h -> build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       copying murmurhash/include/murmurhash/MurmurHash2.h -> build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       creating build/temp.linux-x86_64-cpython-38/murmurhash
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-nvi3ub3d/murmurhash_33cb902f893d43ba8af557908b9b8aee/murmurhash/include -I/home/natalkaser/mmp/Potanin/env3.8/include -I/usr/include/python3.8 -c murmurhash/MurmurHash2.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/MurmurHash2.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-nvi3ub3d/murmurhash_33cb902f893d43ba8af557908b9b8aee/murmurhash/include -I/home/natalkaser/mmp/Potanin/env3.8/include -I/usr/include/python3.8 -c murmurhash/MurmurHash3.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/MurmurHash3.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-nvi3ub3d/murmurhash_33cb902f893d43ba8af557908b9b8aee/murmurhash/include -I/home/natalkaser/mmp/Potanin/env3.8/include -I/usr/include/python3.8 -c murmurhash/mrmr.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/mrmr.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       murmurhash/mrmr.cpp:39:10: fatal error: Python.h: No such file or directory
#          39 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/bin/x86_64-linux-gnu-g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel
jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:969 Сорокин П.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:97 Альджанов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:970 Сорокин П.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:971 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:972 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:973 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:974 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:975 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:976 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:977 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:978 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:979 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:98 Агафонов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:980 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:981 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:982 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:983 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:984 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:985 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:986 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:987 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:988 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:989 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:99 Афанасьев.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:990 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:991 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:992 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:993 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:994 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:995 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:996 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:997 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:998 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/КККМ ОФ 7928:999 Семидалов.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/В Департамент полиции КККМ ОФ 7928:2.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/В Томскую полицию КККМ ОФ 7928:1.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Диплом Енисейского Общества попечения о народном образовании КПД 3693.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Заметки КККМ ОФ 7928:4.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Запрос в полицию КККМ ОФ 7928:2658 .jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Опись пакета КККМ ОФ 7928:1438.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Перечень книг КККМ ОФ 7928:8.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Послужной список КККМ ОФ 7928:1445.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Послужной список КККМ ОФ 7928:1446.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Предания о белом волке КККМ ОФ 7928:18.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Предписание КККМ ОФ 7928:6.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Пропуск в Монголию КККМ ОФ 7928:1450.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Свидетельство КККМ ОФ 7928:1444.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Сказания о Гэсэре КККМ ОФ 7928:17.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Список сказок КККМ ОФ 7928:3.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Справка о буддизме КККМ ОФ 7928:7.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Формуляр библиотеки КККМ ОФ 7928:1449.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Формулярный список КККМ ОФ 7928:1441.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Материалы/Штаб Сибирского округа КККМ ОФ 7928:1447.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/В управление казачьих войск КККМ ОФ 7928:15.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Грудинину КККМ ОФ 7928:14.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Зубашевой КККМ ОФ 7928:12.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Зубашеву КККМ ОФ 7928:10.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Колосову КККМ ОФ 13233:8.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:37.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:38.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:39.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:40.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:41.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:42.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:43.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:44.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:45.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:46.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:47.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:48.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Красноженовой КККМ ОФ 13020:49.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Макерову КККМ ОФ 7928:9.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Неизвестному КККМ ОФ 7928:16.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Новомбергской КККМ ОФ 7928:1530.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Окуличу КККМ ОФ 7928:11.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Потаниной КККМ ОФ 7928:13.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Проскурякову КККМ ОФ 8400:10.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Проскурякову КККМ ОФ 8400:70.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Редакция газеты КККМ ОФ 7928:5.jpeg
#   inflating: /home/natalkaser/mmp/Potanin/КККМ/Письма Потанина/Фарафонтовой КККМ ОФ 7928:1272.jpeg

# %%
print(FOLDER, FOLDER_BIN, sep = "\n")
# Out:
# /home/natalkaser/mmp/Potanin/КККМ
# /home/natalkaser/mmp/Potanin/КККМ_bin/

# %%
import torch
from vit_pytorch import ViT
from models.binae import BinModel
from einops import rearrange
from pathlib import Path
import os

# %% [markdown]
# ## Specify the configurations that you want to use to build your model
#
# Here, pick the desired configuration depending on the weights that you downloaded from our repository. The weights can be downloaded from; https://github.com/dali92002/DocEnTR in the Section Model Zoo.

# %%
THRESHOLD = 0.5  ## binarization threshold after the model output
WORKERS = 4
SPLITSIZE = 256  ## your image will be divided into patches of 256x256 pixels
BATCH_SIZE = 1
OUTPUT_PATH = Path("./demo/cleaned")  #TODO: Add your desired output path here
setting = "base"  ## choose the desired model size [small, base or large], depending on the model you want to use
patch_size = 8  ## choose your desired patch size [8 or 16], depending on the model you want to use
dataset_year = 2018
image_size = (SPLITSIZE, SPLITSIZE)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
if setting == 'base':
    encoder_layers = 6
    encoder_heads = 8
    encoder_dim = 768

elif setting == 'small':
    encoder_layers = 3
    encoder_heads = 4
    encoder_dim = 512

elif setting == 'large':
    encoder_layers = 12
    encoder_heads = 16
    encoder_dim = 1024
else:
    raise ValueError("Invalid setting!")

# %% [markdown]
# ## Build your model
# Build the transformer autoencoder model

# %%
v = ViT(
    image_size=image_size,
    patch_size=patch_size,
    num_classes=1000,
    dim=encoder_dim,
    depth=encoder_layers,
    heads=encoder_heads,
    mlp_dim=2048
)
model = BinModel(
    encoder=v,
    decoder_dim=encoder_dim,
    decoder_depth=encoder_layers,
    decoder_heads=encoder_heads
)

model = model.to(device)

# %% [markdown]
# ## Load the pretrained weights that were downloaded from our repo:
# Here, give the path of the downloaded weights and load them to use a trained model.

# %%
path = "weights"
model_path = Path(path, f"model_{patch_size}_{dataset_year}_{setting}.pt")  # TODO: Add the path to the model weights path here
model.load_state_dict(torch.load(model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
import matplotlib.pyplot as plt

def showimg(img, torch_mode: bool = False):
    if torch_mode:
        img = torch.permute(img, (1, 2, 0))
    plt.figure()
    plt.imshow(img)
    plt.show()
    plt.close()

# %% [markdown]
# ## Read the degraded image
#
# Here specify the location of the degraded image that you want to clean. and then read it. We also can visualize it before cleaning. Here I have a folder named demo that contain two folders named degraded and cleaned, the degraded contain the degraded image and the cleaned will contain later the obtained results. But you can specify your own names of folders.

# %%
import math

from torch.utils.data import Dataset, DataLoader
from typing import Dict, Any, List, Tuple, Optional
from numpy.typing import ArrayLike
import numpy as np
import cv2

import torch

Height = int
Width = int

ImageShape = Tuple[Height, Width]


class BinarisationDataset(Dataset):
    def __init__(
            self,
            fnames: List[Path],
            imshape: Optional[ImageShape] = None,
    ) -> None:
        super().__init__()
        self.fnames = fnames
        self.imshape = imshape

    def __len__(self) -> int:
        return len(self.fnames)

    def __getitem__(self, item: int) -> Dict[str, Any]:
        img, og_shape, rs_shape = self._load_image(self.fnames[item])
        img = torch.tensor(img)
        return {
            "img": img,
            "og_shape": og_shape,
            "rs_shape": rs_shape,
            "fn_shape": self.imshape or (img.shape[0], img.shape[1]),
            "fname": self.fnames[item],
        }

    def _load_image(self, path: Path) -> Tuple[ArrayLike, ImageShape, ImageShape]:
        img = cv2.imread(str(path))
        og_shape = img.shape[0], img.shape[1]

        if self.imshape is not None:
            img, rs_shape = self._proportional_scaling(img)
        else:
            rs_shape = og_shape

        # This is a bug of the original training of the model. The code expects
        # OpenCV BGR images, but it normalises using RGB constants. If you re-train,
        # take this into consideration and switch the code approppriately.
        # Otherwise, if using the official checkpoints, you should use this code
        # as is.
        # Thankfully, thanks to the magic of Deep Learning(tm), the model works
        # regardless.

        # img = (cv2.cvtColor(img, cv2.COLOR_BGR2RGB) / 255).astype('float32')  # height, width, 3
        img = (img / 255).astype('float32')  # height, width, 3

        return img, og_shape, rs_shape

    def _proportional_scaling(self, img: ArrayLike) -> Tuple[ArrayLike, ImageShape]:
        """Scale image to a set width and height with padding."""
        img_height, img_width, img_channels = img.shape

        assert self.imshape is not None, "No resizing should be done if shape is None"
        height, width = self.imshape

        factor = min(height / img_height, width / img_width)
        new_height, new_width = int(img_height * factor + 0.999), int(
            img_width * factor + 0.999
        )

        img = cv2.resize(img, (new_width, new_height))
        padded = np.zeros((*self.imshape, img_channels), dtype=img.dtype)
        padded[:new_height, :new_width, :] = img

        return padded, (new_height, new_width)

    # You can implement your own dataset by writing a function that selects the images
    # to clean and passes them to the constructor as a list.
    @classmethod
    def from_old_docs(cls, root_path: Path, imshape: Optional[ImageShape]) -> "BinarisationDataset":
        return BinarisationDataset(list(root_path.glob("*/*.jpg")), imshape)

# %% [markdown]
# ## Split and Merge functions
#
# Here, two function that are used for splitting an image into patches and merge a list of patches into an image.

# %%
class PatchProcessor:
    MEAN = torch.Tensor(np.array([0.485, 0.456, 0.406]))
    STD = torch.Tensor(np.array([0.229, 0.224, 0.225]))

    def __init__(self, nsize1: int, nsize2: int) -> None:
        self.nsize1 = nsize1
        self.nsize2 = nsize2

    def split(self, img: torch.Tensor) -> torch.Tensor:
        """Convert image into a set of patches."""
        # im: h x w x 3
        patches = rearrange(img, "(h p1) (w p2) c -> (h w) p1 p2 c", p1=self.nsize1, p2=self.nsize2, c=3)
        return patches

    def merge_image(self, patches: torch.Tensor, h: int, w: int) -> torch.Tensor:
        """Convert patches back into an image."""
        #patches: npatches x hpatch x wpatch x 3
        img = rearrange(patches, "(h w) p1 p2 c -> (h p1) (w p2) c", p1=self.nsize1, p2=self.nsize2, c=3,
                        h=h // self.nsize1, w=w // self.nsize2)
        return img

    def normalize_patches(self, patches: torch.Tensor) -> torch.Tensor:
        """Apply normalization on the color of the patches."""
        # patches: npatches x hpatch x wpatch x 3
        patches = (patches - self.MEAN[None, None, None, :]) / self.STD[None, None, None, :]
        return patches

    def unnormalize_patches(self, patches: torch.Tensor):
        # patches: npatches x hpatch x wpatch x 3
        patches = (patches * self.STD[None, None, None, :]) + self.MEAN[None, None, None, :]
        return patches

    @staticmethod
    def _closest_multiple(num: int, multiple: int) -> int:
        return (math.ceil(num / multiple)) * multiple

    def prepare_image(self, image: torch.Tensor):
        """Split the image intop patches, an image is padded first to make it dividable by the split size."""
        # image: h x w x 3
        h = self._closest_multiple(image.shape[0], self.nsize1)
        w = self._closest_multiple(image.shape[1], self.nsize2)

        image_padded = torch.ones((h, w, 3))
        image_padded[:image.shape[0], :image.shape[1], :] = image
        patches = self.split(image_padded)
        patches = self.normalize_patches(patches)
        # patches: npatches x hpatch x wpatch x 3
        return patches

    def unprepare_image(self, patches, rs_shape: ImageShape, fn_shape: ImageShape) -> torch.Tensor:
        # patches: npatches x hpatch x wpatch x 3
        h = self._closest_multiple(fn_shape[0], self.nsize1)
        w = self._closest_multiple(fn_shape[1], self.nsize2)

        patches = self.unnormalize_patches(patches)
        image = self.merge_image(patches, h, w)

        # image: h' x w' x 3
        image = image[:rs_shape[0], :rs_shape[1], :]

        return image


class PatchCollator:
    def __init__(self):
        self.processor = PatchProcessor(SPLITSIZE, SPLITSIZE)

    def get_processor(self) -> PatchProcessor:
        return self.processor

    def collate_fn(self, batch):
        output = {
            "patches": [],
            "npatches": [],
            "end_indices": [],
            "fnames": [],
            "og_shapes": [],
            "rs_shapes": [],
            "fn_shapes": [],
        }
        for sample in batch:
            img, og_shape, rs_shape, fn_shape, fname = sample["img"], sample["og_shape"], sample["rs_shape"], sample[
                "fn_shape"], sample["fname"]
            patches = self.processor.prepare_image(img)
            output["patches"].append(patches)
            output["npatches"].append(len(patches))
            output["fnames"].append(fname)
            output["og_shapes"].append(og_shape)
            output["rs_shapes"].append(rs_shape)
            output["fn_shapes"].append(fn_shape)
            output["end_indices"].append(
                len(patches) if len(output["end_indices"]) == 0 else output["end_indices"][-1] + len(patches))
        output["patches"] = torch.cat(output["patches"], dim=0)
        return output

# %%
collator = PatchCollator()
dataset = BinarisationDataset(list(Path("./demo/degraded/").glob("*")))  # TODO: Change your dataset here
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collator.collate_fn,
                        num_workers=WORKERS, pin_memory=False, drop_last=False)

# %%
showimg(dataset[1]["img"])

# %% [markdown]
# ## Clean your image with the trained model
#
# Clean your list of patches obe by one.

# %%
def export_image(pred_patches: torch.Tensor, batch: Dict[str, Any]) -> None:
    prev = 0
    if not os.path.exists(OUTPUT_PATH):
        os.makedirs(OUTPUT_PATH)
    for jj, (end_ind, og_shape, rs_shape, fn_shape, fname) in enumerate(
            zip(batch["end_indices"], batch["og_shapes"], batch["rs_shapes"], batch["fn_shapes"], batch["fnames"])):
        img_patches = pred_patches[prev: end_ind]
        img_clean = processor.unprepare_image(img_patches, rs_shape, fn_shape)
        prev = end_ind
        img_clean = (img_clean.numpy() > THRESHOLD) * 255
        img_clean = img_clean.astype(np.uint8)
        cv2.imwrite(str(OUTPUT_PATH / f"{fname.stem}.png"), cv2.cvtColor(img_clean, cv2.COLOR_RGB2BGR))

# %%
from multiprocessing.pool import ThreadPool

thread_pool = ThreadPool(8 - WORKERS)
result = []
processor = collator.get_processor()

for ii, batch in enumerate(dataloader):
    train_in = batch["patches"]

    with torch.no_grad():
        train_in = train_in.to(device)
        train_in = train_in.permute(0, 3, 1, 2)  # b, ch, h, w
        any_img = torch.rand(train_in.shape).to(device)
        _, _, pred_patches = model(train_in, any_img)
        pred_patches = torch.squeeze(
            rearrange(pred_patches, 'b (h w) (p1 p2 c) -> b (h p1) (w p2) c', p1=patch_size, p2=patch_size,
                      h=image_size[0] // patch_size))
        pred_patches = pred_patches.detach().cpu()
        export_thread = thread_pool.apply(export_image, [pred_patches, batch])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
